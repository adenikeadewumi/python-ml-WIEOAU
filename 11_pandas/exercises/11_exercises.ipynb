# %% [markdown]
# <a href="https://colab.research.google.com/github/adenikeadewumi/python-ml-WIEOAU/blob/master/11_pandas/exercises/11_exercises.ipynb" target="_parent">
# <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # 📝 Exercises — Module 11: Pandas
# ---

# %% [markdown]
# ### Exercise 1
# Create a DataFrame with 5 columns (id, name, department, salary, years_experience) and at least 8 rows. Find the average salary by department.

# %%
import pandas as pd
# Your code here

# %% [markdown]
# ### Exercise 2
# Given the DataFrame, find all employees earning above the median salary in their department.

# %%
# Your code here (use df from Exercise 1)

# %% [markdown]
# ### Exercise 3
# Introduce 3 missing values to the salary column. Then fill them in with the department median salary.

# %%
# Your code here

# %% [markdown]
# ### Exercise 4 — Challenge
# Load a CSV from a URL and perform a mini-EDA (exploratory data analysis): shape, dtypes, missing values, numerical summary, and one interesting finding.

# %%
import pandas as pd
# Using a built-in sample dataset
url = 'https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv'
# df = pd.read_csv(url)  # uncomment if you have internet
# Your analysis here
