# %% [markdown]
# <a href="https://colab.research.google.com/github/adenikeadewumi/Python-programming-for-ML-WIEOAU/blob/main/04_functions/exercises/04_exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📝 Exercises — Module 04: Functions
# ---

# %% [markdown]
# ### Exercise 1
# Write a function `celsius_to_fahrenheit(c)` that converts Celsius to Fahrenheit (`F = C * 9/5 + 32`). Test it with 0, 100, and 37.

# %%
# Your code here

# %% [markdown]
# ### Exercise 2
# Write a function `is_palindrome(s)` that returns `True` if a string reads the same forwards and backwards (ignore case and spaces). Test with 'racecar', 'A man a plan a canal Panama', 'hello'.

# %%
# Your code here

# %% [markdown]
# ### Exercise 3
# Write a function `count_vowels(text)` that returns the number of vowels in a string.

# %%
# Your code here

# %% [markdown]
# ### Exercise 4
# Write a function using `**kwargs` called `make_tag(tag, **attributes)` that returns an HTML tag string.
# Example: `make_tag('a', href='https://python.org', class_='link')` → `<a href='https://python.org' class='link'>`

# %%
# Your code here

# %% [markdown]
# ### Exercise 5 — Challenge
# Write a `memoize` decorator that caches the results of a function. Then apply it to a recursive Fibonacci function and compare its speed with and without memoization.

# %%
# Your code here
