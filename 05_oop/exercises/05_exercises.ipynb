# %% [markdown]
# <a href="https://colab.research.google.com/github/adenikeadewumi/Python-programming-for-ML-WIEOAU/blob/main/05_oop/exercises/05_exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📝 Exercises — Module 05: OOP
# ---

# %% [markdown]
# ### Exercise 1
# Create a `Rectangle` class with `width` and `height`. Add methods `area()`, `perimeter()`, and `is_square()`. Add a `__str__` that returns `'Rectangle(4x6)'`.

# %%
# Your code here

# %% [markdown]
# ### Exercise 2
# Create a `Student` class that stores a name and a list of grades. Add methods `add_grade()`, `average()`, `highest()`, and `lowest()`.

# %%
# Your code here

# %% [markdown]
# ### Exercise 3 — Challenge
# Build a simple `Stack` class (LIFO structure) with `push()`, `pop()`, `peek()`, `is_empty()`, and `size()`. Implement `__repr__`.

# %%
# Your code here
