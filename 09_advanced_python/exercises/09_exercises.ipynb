# %% [markdown]
# <a href="https://colab.research.google.com/github/adenikeadewumi/python-ml-WIEOAU/blob/main/09_advanced_python/exercises/09_exercises.ipynb" target="_parent">
# <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # 📝 Exercises — Module 09: Advanced Python
# ---

# %% [markdown]
# ### Exercise 1
# Using a list comprehension, create a list of all prime numbers below 100.

# %%
# Your code here

# %% [markdown]
# ### Exercise 2
# Write a generator function `running_average(numbers)` that yields the running average as each number is added.

# %%
# Your code here

# %% [markdown]
# ### Exercise 3
# Write a context manager class `SuppressErrors(*exception_types)` that silently catches specified exceptions.

# %%
# Your code here

# %% [markdown]
# ### Exercise 4
# Using `collections.Counter`, find the top-5 most common words in a passage (ignore case, punctuation).

# %%
passage = '''
To be or not to be that is the question whether tis nobler in the mind
to suffer the slings and arrows of outrageous fortune or to take arms against
a sea of troubles and by opposing end them
'''
# Your code here
