# %% [markdown]
# <a href="https://colab.research.google.com/github/adenikeadewumi/python-ml-WIEOAU/blob/main/10_numpy/exercises/10_exercises.ipynb" target="_parent">
# <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # 📝 Exercises — Module 10: NumPy
# ---

# %% [markdown]
# ### Exercise 1
# Create a 5×5 matrix where the diagonal values are 1–5 and everything else is 0.

# %%
import numpy as np
# Your code here

# %% [markdown]
# ### Exercise 2
# Given a 1D array of 1000 random normal values, compute the proportion that fall within 1, 2, and 3 standard deviations of the mean.

# %%
import numpy as np
rng = np.random.default_rng(42)
data = rng.normal(loc=50, scale=10, size=1000)
# Your code here

# %% [markdown]
# ### Exercise 3
# Without loops, normalise a matrix so each row has mean 0 and std 1 (row-wise z-score normalisation).

# %%
import numpy as np
rng = np.random.default_rng(42)
matrix = rng.integers(1, 100, size=(4, 5)).astype(float)
# Your code here

# %% [markdown]
# ### Exercise 4 — Challenge
# Implement cosine similarity between two vectors using only NumPy.
# `cos(u,v) = (u·v) / (||u|| * ||v||)`

# %%
import numpy as np
u = np.array([1, 2, 3, 4])
v = np.array([4, 3, 2, 1])
# Your code here
