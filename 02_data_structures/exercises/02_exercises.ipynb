# %% [markdown]
# <a href="https://colab.research.google.com/github/adenikeadewumi/Python-programming-for-ML-WIEOAU/blob/main/02_data_structures/exercises/02_exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📝 Exercises — Module 02: Data Structures
# ---

# %% [markdown]
# ### Exercise 1
# Create a list of 5 of your favourite movies. Append one more, then remove the second one. Print the final list.

# %%
# Your code here

# %% [markdown]
# ### Exercise 2
# Given `nums = [5, 3, 8, 1, 9, 2, 7]`, sort it in descending order without modifying the original. *(Hint: `sorted()` returns a new list)*

# %%
nums = [5, 3, 8, 1, 9, 2, 7]
# Your code here

# %% [markdown]
# ### Exercise 3
# Create a dictionary representing a person (name, age, city, job). Add a 'salary' key, then print all key-value pairs using a for loop.

# %%
# Your code here

# %% [markdown]
# ### Exercise 4
# Given two lists, find the elements that appear in both:
# ```python
# list1 = [1, 2, 3, 4, 5, 6]
# list2 = [4, 5, 6, 7, 8, 9]
# ```
# *(Hint: convert to sets)*

# %%
list1 = [1, 2, 3, 4, 5, 6]
list2 = [4, 5, 6, 7, 8, 9]
# Your code here

# %% [markdown]
# ### Exercise 5
# Count how many times each word appears in the sentence:
# `'the cat sat on the mat and the cat ate the rat'`
# *(Use a dict)*

# %%
sentence = 'the cat sat on the mat and the cat ate the rat'
# Your code here

# %% [markdown]
# ### Exercise 6 — Challenge
# You have student records as a list of dicts. Find the student with the highest average grade.
# ```python
# students = [
#     {'name': 'Alice', 'grades': [85, 92, 88]},
#     {'name': 'Bob',   'grades': [70, 75, 80]},
#     {'name': 'Carol', 'grades': [95, 91, 97]},
# ]
# ```

# %%
students = [
    {'name': 'Alice', 'grades': [85, 92, 88]},
    {'name': 'Bob',   'grades': [70, 75, 80]},
    {'name': 'Carol', 'grades': [95, 91, 97]},
]
# Your code here
