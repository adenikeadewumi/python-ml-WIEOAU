# %% [markdown]
# <a href="https://colab.research.google.com/github/adenikeadewumi/python-ml-WIEOAU/blob/master/01_python_basics/exercises/01_exercises.ipynb" target="_parent">
# <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # 📝 Exercises — Module 01: Python Basics
# > Complete each exercise. Hint cells are hidden — try first before peeking!
#
# ---

# %% [markdown]
# ### Exercise 1
# Create variables for your name, age, and favourite programming language. Print a sentence using f-strings.

# %%
# Your code here

# %% [markdown]
# ### Exercise 2
# Convert the string `'3.14159'` to a float and multiply it by 2. Print the result rounded to 3 decimal places.

# %%
# Your code here

# %% [markdown]
# ### Exercise 3
# Given `s = 'Data Science is awesome!'`, extract just the word `'Science'` using slicing.

# %%
s = 'Data Science is awesome!'
# Your code here

# %% [markdown]
# ### Exercise 4
# Write a single expression that checks if a number `n = 17` is between 10 and 20 (inclusive). It should print `True`.

# %%
n = 17
# Your code here

# %% [markdown]
# ### Exercise 5
# A store sells apples for £0.50 each. Write code that calculates the total cost for 13 apples and prints:
# `'13 apples cost £6.50'`

# %%
# Your code here

# %% [markdown]
# ### Exercise 6
# Use string methods to:
# 1. Make `'  HELLO WORLD  '` lowercase and stripped of whitespace
# 2. Replace all spaces with underscores

# %%
text = '  HELLO WORLD  '
# Your code here

# %% [markdown]
# ### Exercise 7 — Challenge
# Without running the code first, predict the output of each print statement. Then verify.
# ```python
# x = 7
# print(x // 2)
# print(x % 2)
# print(x ** 2)
# print(x / 2)
# print(bool(0), bool(1), bool(""), bool("hi"))
# ```

# %%
x = 7
print(x // 2)
print(x % 2)
print(x ** 2)
print(x / 2)
print(bool(0), bool(1), bool(""), bool("hi"))

# %% [markdown]
# ### Exercise 8 — FizzBuzz Lite
# Print numbers 1–15. For multiples of 3, print 'Fizz' instead. For multiples of 5, print 'Buzz'. For multiples of both, print 'FizzBuzz'.
# *(Hint: use `%` operator and a loop — loops are covered in Module 03, but try it!)*

# %%
# Your code here

# %% [markdown]
# ---
# ## ✅ Solutions
# See `01_exercises_solutions.ipynb` (available after you try!)
