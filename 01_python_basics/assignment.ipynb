# %% [markdown]
# <a href="https://colab.research.google.com/github/adenikeadewumi/python-ml-WIEOAU/blob/main/01_python_basics/assignment.ipynb" target="_parent">
# <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # 📝 Assignment 01: Variables, Data Types & Operators
# **Module 01 — Python Programming for ML**
#
# **Name:** ______________________
#
# **Date:** ______________________
#
# ---

# %% [markdown]
# ### Instructions
# 1. Answer all questions by writing your code in the designated cells.
# 2. Do not change the existing variable definitions or framework provided.
# 3. Ensure your notebook runs sequentially without errors (`Cell` -> `Run All`) before submitting.

# %% [markdown]
# ---
# ## Section 1: Variable Basics & Swapping (3 Marks)

# %% [markdown]
# ### Question 1.1
# Correct the invalid variable names below so that they follow Python's rules and best practices (`snake_case`). Reassign them to their respective values.

# %%
# Fix the names below:
# 1st_student_name = "Chidi"
# student-age = 21
# Class = "EEE 311"

# Your corrected code here:

# %% [markdown]
# ### Question 1.2
# Given the variables `val_a` and `val_b`, swap their contents **elegantly** in a single line of code without creating a temporary standalone third variable. Print the final results using an f-string.

# %%
val_a = "Hardware"
val_b = "Software"

# Your elegant swap here:


# Print output confirming the swap:

# %% [markdown]
# ---
# ## Section 2: Type Casting & Truthiness (4 Marks)

# %% [markdown]
# ### Question 2.1
# A sensor sends data as a string: `sensor_reading = "185.76"`.
# 1. Convert `sensor_reading` to a floating-point number.
# 2. Cast that resulting float directly into an integer (observe what happens to the decimal).
# 3. Print both the value and the python data type of your final integer variable.

# %%
sensor_reading = "185.76"

# Your multi-step type casting code here:

# %% [markdown]
# ### Question 2.2
# Without executing the cell, write down your prediction (`True` or `False`) for the truthiness of the following variables in the markdown cell below. Then, write code using `bool()` to verify your answers.

# %% [markdown]
# #### Write Predictions Here:
# - `item_a` prediction: _______
# - `item_b` prediction: _______
# - `item_c` prediction: _______
# - `item_d` prediction: _______

# %%
item_a = 0.0
item_b = " "
item_c = "False"
item_d = None

# Verification code here:
print(bool(item_a))
print(bool(item_b))
print(bool(item_c))
print(bool(item_d))

# %% [markdown]
# ---
# ## Section 3: Advanced String Indexing & Slicing (5 Marks)
#
# Hint: Use google or chatgpt to understand slicing and indexing

# %% [markdown]
# ### Question 3.1
# Given the string variable `dataset_info`, complete the following tasks using slicing or indexing:
# 1. Extract and print the substring `"YOLOv8"`.
# 2. Extract and print the last character of the string using a **negative index**.
# 3. Reverse the entire string completely using step slicing.

# %%
dataset_info = "Model: YOLOv8; Accuracy: 94.2%"

# 1. Extract "YOLOv8"


# 2. Extract last character using negative index


# 3. Reverse the string

# %% [markdown]
# ### Question 3.2
# Clean up the following messy log entry using string methods. You must achieve this in **one chained line** of code:
# 1. Remove leading and trailing spaces.
# 2. Replace all instances of `"ERR"` with `"ERROR"`.
# 3. Convert the entire message to uppercase.

# %%
log_entry = "   system status: critical ERR encountered in core   "

# Your single chained clean-up statement here:
cleaned_log =

print(cleaned_log)

# %% [markdown]
# ---
# ## Section 4: Arithmetic & Logical Pipelines (5 Marks)

# %% [markdown]
# ### Question 4.1
# An automated production assembly line packages eggs into boxes. A batch contains exactly **512 eggs**. A standard box holds exactly **12 eggs**.
# 1. Use floor division (`//`) to find out how many full boxes can be filled.
# 2. Use the modulo operator (`%`) to find how many leftover eggs cannot fit into a full box.
# 3. Print your final calculation explicitly using an f-string matching this format:
# `512 eggs will fill 42 boxes with 8 leftover eggs.` (Note: Replace values dynamically using variables)

# %%
total_eggs = 512
box_capacity = 12

# Calculations:
filled_boxes =
leftover_eggs =

# Dynamic f-string print statement:

# %% [markdown]
# ### Question 4.2
# Write a **chained comparison** expression that verifies if an engineering component's efficiency value `eff = 0.88` is strictly greater than `0.75` and less than or equal to `0.90`. Print the direct Boolean outcome.

# %%
eff = 0.88

# Write evaluation here using Python's chained comparison syntax:
is_in_range =

print(is_in_range)

# %% [markdown]
# ---
# ## Section 5: Advanced Formatting Challenge (3 Marks)

# %% [markdown]
# ### Question 5.1
# Generate a clean terminal report using an f-string loop format that precisely matches the structured look below. Pay special attention to alignment, string padding (`<` or `>`), and numeric precision formatting:
#
# ```text
# Metrics Overview
# =====================
# Loss       --> 0.0421
# Precision  --> 0.9570
# Recall     --> 0.8900
# ```

# %%
loss_val = 0.042135
prec_val = 0.957
rec_val = 0.89

# Write a multi-line format report ensuring numeric specs display up to 4 decimal places:
formatted_report = f"""
# Your formatting layout implementation here
"""

print(formatted_report)
