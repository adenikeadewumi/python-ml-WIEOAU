# %% [markdown]
# <a href="https://colab.research.google.com/github/adenikeadewumi/python-ml-WIEOAU/blob/main/00_setup/00_environment_check.ipynb" target="_parent">
# <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # 00 — Environment Check
# Run every cell below. If you see ✅ after each one, you're ready to go!

# %%
import sys
print(f"Python version: {sys.version}")
assert sys.version_info >= (3, 8), "Please upgrade to Python 3.8+"
print("✅ Python version OK")

# %%
packages = ["numpy","pandas","matplotlib","seaborn","sklearn"]
for p in packages:
    try:
        __import__(p)
        print(f"✅ {p}")
    except ImportError:
        print(f"❌ {p} — run: pip install {p}")

# %% [markdown]
# ## 🎉 If all checks pass, open `01_python_basics/01_variables_and_types.ipynb` to begin!
